# %%
import os
import pandas as pd
from ebmdatalab import bq

# %%
sql = f"""
WITH
  drugs AS (
  SELECT
    DATE(i.month) AS month, -- Converts TIMESTAMP TO DATE (AS it's always just 1st OF month) 
    regional_team,
    bnf_name,
    chemical,
    SUM(items) AS items,
    SUM(quantity) AS quantity,
  FROM
    ebmdatalab.hscic.normalised_prescribing AS i
  INNER JOIN
    ebmdatalab.hscic.practices prac
  ON
    practice = prac.code
    AND setting = 4
  INNER JOIN
    hscic.bnf AS bnf
  ON
    i.bnf_code = bnf.presentation_code
  WHERE
    i.bnf_code LIKE '0212000AM%' -- Inclisiran
  GROUP BY
    month,
    bnf_name,
    regional_team,
    chemical ),
  list AS (
  SELECT
    DATE(month) AS month,
    regional_team_id,
    SUM(total_list_size) AS total_list_size
  FROM
    hscic.practice_statistics AS stats
  INNER JOIN
    hscic.ccgs AS ccgs
  ON
    stats.pct_id = ccgs.code
  GROUP BY
    month,
    regional_team_id )
SELECT
  drugs.month AS month,
  regional_team,
  chemical,
  bnf_name,
  items,
  quantity,
  total_list_size,
  IEEE_DIVIDE(items, total_list_size) AS rate
FROM
  drugs
INNER JOIN
  list
ON
  drugs.regional_team = list.regional_team_id
  AND drugs.month = list.month 

"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'inclisiran_list.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/query.py:86, in try_query(connector, query_fn)
#      85     logger.debug("Requesting query... ")
# ---> 86     return query_fn()
#      87 except concurrent.futures.TimeoutError as ex:
#
# File /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/client.py:3590, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#    3586 job_config = _job_helpers.job_config_with_defaults(
#    3587     job_config, self._default_query_job_config
#    3588 )
# -> 3590 return _job_helpers.query_and_wait(
#    3591     self,
#    3592     query,
#    3593     job_config=job_config,
#    3594     location=location,
#    3595     project=project,
#    3596     api_timeout=api_timeout,
#    3597     wait_timeout=wait_timeout,
#    3598     retry=retry,
#    3599     job_retry=job_retry,
#    3600     page_size=page_size,
#    3601     max_results=max_results,
#    3602 )
#
# File /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/_job_helpers.py:506, in query_and_wait(client, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#     505 if job_retry is not None:
# --> 506     return job_retry(do_query)()
#     507 else:
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/_job_helpers.py:447, in query_and_wait.<locals>.do_query()
#     446 if retry is not None:
# --> 447     response = retry(client._call_api)(
#     448         retry=None,  # We're calling the retry decorator ourselves.
#     449         span_name="BigQuery.query",
#     450         span_attributes=span_attributes,
#     451         method="POST",
#     452         path=path,
#     453         data=request_body,
#     454         timeout=api_timeout,
#     455     )
#     456 else:
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File /usr/local/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File /usr/local/lib/python3.12/site-packages/google/cloud/bigquery/client.py:831, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     828     with create_span(
#     829         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     830     ):
# --> 831         return call()
#     833 return call()
#
# File /usr/local/lib/python3.12/site-packages/google/cloud/_http/__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#
# BadRequest: 400 POST https://bigquery.googleapis.com/bigquery/v2/projects/ebmdatalab/queries?prettyPrint=false: SELECT list expression references i.stp which is neither grouped nor aggregated at [11:5]
#
# The above exception was the direct cause of the following exception:
#
# GenericGBQException                       Traceback (most recent call last)
# Cell In[7], line 68
#      65 csv_path = os.path.join('..', 'data', 'inclisiran_list.csv')
#      67 # Use the cached_read function from the bq library to run the query.
# ---> 68 vtm_matched = bq.cached_read(sql, csv_path=csv_path)
#
# File /usr/local/lib/python3.12/site-packages/ebmdatalab/bq.py:54, in cached_read(sql, csv_path, use_cache, **kwargs)
#      50 os.makedirs(csv_dir, exist_ok=True)
#      51 temp_path = os.path.join(
#      52     csv_dir, '.tmp{}.{}'.format(_random_str(8), csv_filename)
#      53 )
# ---> 54 df = pandas_gbq.read_gbq(sql, **defaults)
#      55 df.to_csv(temp_path, index=False)
#      56 old_fingerprint_files = glob.glob(
#      57     os.path.join(csv_dir, "." + csv_filename + ".*.tmp")
#      58 )
#
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/gbq.py:846, in read_gbq(query_or_table, project_id, index_col, columns, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes, auth_redirect_uri, client_id, client_secret, col_order)
#     831 connector = GbqConnector(
#     832     project_id,
#     833     reauth=reauth,
#    (...)
#     842     client_secret=client_secret,
#     843 )
#     845 if _is_query(query_or_table):
# --> 846     final_df = connector.run_query(
#     847         query_or_table,
#     848         configuration=configuration,
#     849         max_results=max_results,
#     850         progress_bar_type=progress_bar_type,
#     851         dtypes=dtypes,
#     852     )
#     853 else:
#     854     final_df = connector.download_table(
#     855         query_or_table,
#     856         max_results=max_results,
#     857         progress_bar_type=progress_bar_type,
#     858         dtypes=dtypes,
#     859     )
#
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/gbq.py:420, in GbqConnector.run_query(self, query, max_results, progress_bar_type, **kwargs)
#     417 job_config = bigquery.QueryJobConfig.from_api_repr(job_config_dict)
#     419 if FEATURES.bigquery_has_query_and_wait:
# --> 420     rows_iter = pandas_gbq.query.query_and_wait_via_client_library(
#     421         self,
#     422         self.client,
#     423         query,
#     424         location=self.location,
#     425         project_id=self.project_id,
#     426         job_config=job_config,
#     427         max_results=max_results,
#     428         timeout_ms=timeout_ms,
#     429     )
#     430 else:
#     431     rows_iter = pandas_gbq.query.query_and_wait(
#     432         self,
#     433         self.client,
#    (...)
#     439         timeout_ms=timeout_ms,
#     440     )
#
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/query.py:199, in query_and_wait_via_client_library(connector, client, query, job_config, location, project_id, max_results, timeout_ms)
#     188 def query_and_wait_via_client_library(
#     189     connector,
#     190     client: bigquery.Client,
#    (...)
#     197     timeout_ms: Optional[int],
#     198 ):
# --> 199     rows_iter = try_query(
#     200         connector,
#     201         functools.partial(
#     202             client.query_and_wait,
#     203             query,
#     204             job_config=job_config,
#     205             location=location,
#     206             project=project_id,
#     207             max_results=max_results,
#     208             wait_timeout=timeout_ms / 1000.0 if timeout_ms else None,
#     209         ),
#     210     )
#     211     logger.debug("Query done.\n")
#     212     return rows_iter
#
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/query.py:100, in try_query(connector, query_fn)
#      95         raise pandas_gbq.exceptions.AccessDenied(
#      96             "The credentials have been revoked or expired, "
#      97             f"please re-run the application to re-authorize: {ex}"
#      98         )
#      99 except connector.http_error as ex:
# --> 100     connector.process_http_error(ex)
#
# File /usr/local/lib/python3.12/site-packages/pandas_gbq/gbq.py:368, in GbqConnector.process_http_error(ex)
#     366     raise TableCreationError(f"Reason: {error_message}")
#     367 else:
# --> 368     raise GenericGBQException("Reason: {0}".format(ex)) from ex
#
# GenericGBQException: Reason: 400 POST https://bigquery.googleapis.com/bigquery/v2/projects/ebmdatalab/queries?prettyPrint=false: SELECT list expression references i.stp which is neither grouped nor aggregated at [11:5]
