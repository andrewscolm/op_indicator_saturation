# %%
import os
import pandas as pd
from ebmdatalab import bq

# %%
sql = f"""
SELECT * FROM hscic.practice_statistics
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'practice_statistics.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.stps
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'stps.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.normalised_prescribing
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'normalised_prescribing.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.practices
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'practices.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.bnf
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'bnf.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.ccgs
LIMIT 3;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'ccgs.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.prescribing_setting
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data','table_heads', 'prescribing_setting.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)

# %%
sql = f"""
SELECT * FROM hscic.practices
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'practices.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
sql = f"""
SELECT * FROM hscic.practice_statistics
WHERE
    month >= '2020-01-01'
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'practice_statistics.csv')

# Use the cached_read function from the bq library to run the query.
vtm_matched = bq.cached_read(sql, csv_path=csv_path)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
